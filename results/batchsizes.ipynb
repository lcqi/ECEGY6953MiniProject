# %%
# %pip install torch
# %pip install torchvision
# %pip install torchsummary
# Out:
# Requirement already satisfied: torch in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.13.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.5.0)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: numpy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.23.4)
# Requirement already satisfied: torch==1.13.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.13.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (8.5.0.96)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (65.5.0)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (0.37.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (1.26.12)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchsummary in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchsummary import summary

# %%
#choose device
if torch.cuda.is_available():
    device=torch.device('cuda')
else:
    device=torch.device('cpu')

# %% [markdown]
# 1. Epoch, batchsize, learning rate都能调整

# %%
epochs=50
#batch_size=64
batch_sizes=[32,64,128,256]
learning_rate=0.01

# %% [markdown]
# 2. transform的方法也能调整

# %%
#define transform
train_transform=transforms.Compose(
    [transforms.Pad(4),
     transforms.RandomCrop(32),
     transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
     transforms.Normalize(mean=[0.485,0.456,0.406],
                          std=[0.229,0.224,0.225])])
valid_transform=transforms.Compose(
    [
     transforms.ToTensor(),
     transforms.Normalize(mean=[0.485,0.456,0.406],
                          std=[0.229,0.224,0.225])])

# %%
# download cifar-10 dataset
train_dataset=torchvision.datasets.CIFAR10(root='../data/',
                                           train=True,
                                           transform=train_transform,
                                           download=True)
test_dataset=torchvision.datasets.CIFAR10(root='../data/',
                                           train=False,
                                           transform=valid_transform,
                                           download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# define data loader
#train_loader=torch.utils.data.DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
#test_loader=torch.utils.data.DataLoader(test_dataset,batch_size=batch_size,shuffle=False)

# %%
# residual block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1=nn.Conv2d(in_channels=in_channels,out_channels=out_channels,stride=stride,kernel_size=3,padding=1,bias=False)
        self.bn1=nn.BatchNorm2d(out_channels)
        self.relu=nn.ReLU(inplace=True)
        self.conv2=nn.Conv2d(in_channels=out_channels,out_channels=out_channels,stride=1,kernel_size=3,padding=1,bias=False)
        self.bn2=nn.BatchNorm2d(out_channels)
        self.downsample=nn.Sequential()
        if (stride!=1) or(in_channels!=out_channels):
            self.downsample=nn.Sequential(
                nn.Conv2d(in_channels=in_channels,out_channels=out_channels,stride=stride,kernel_size=1,bias=False),
                nn.BatchNorm2d(out_channels))
    def forward(self,x):
        out=self.conv1(x)
        out=self.bn1(out)
        out=self.relu(out)
        out=self.conv2(out)
        out=self.bn2(out)
        out+=self.downsample(x)
        out=self.relu(out)
        return out

# %%
# 4-layer ResNet
class ResNet(nn.Module):
    def __init__(self,block,layers,num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels=64                                                  # 64 can be modified
        self.conv=nn.Conv2d(in_channels=3,out_channels=64,stride=1,kernel_size=3,padding=1,bias=False)
        self.bn=nn.BatchNorm2d(64)
        self.relu=nn.ReLU(inplace=True)
        self.layer1=self.make_layer(block, 64,layers[0], stride=1)        # 64 can be modified
        self.layer2=self.make_layer(block, 128, layers[1], stride=2)      # 128 can be modified
        self.layer3=self.make_layer(block, 256, layers[2], stride=2)      # 256 can be modified
        #self.layer4=self.make_layer(block, 512, layers[3], stride=2)      # 512 can be modified
        self.avg_pool=nn.AvgPool2d(8)                                        # 4 can be modified
        self.fc=nn.Linear(256,10) 
        
    def make_layer(self,block,out_channels,blocks, stride):
        layers=[]
        layers.append(block(self.in_channels,out_channels,stride))
        self.in_channels=out_channels
        for i in range(1,blocks):
            layers.append(block(out_channels,out_channels,stride=1))
        return nn.Sequential(*layers)
    
    def forward(self,x):
        out=self.conv(x)
        out=self.bn(out)
        out=self.relu(out)
        out=self.layer1(out)
        out=self.layer2(out)
        out=self.layer3(out)
        #out=self.layer4(out)
        out=self.avg_pool(out)
        out=out.view(out.size(0),-1)
        out=self.fc(out)
        return out

# %%
model=ResNet(ResidualBlock,[2,2,2]).to(device)
summary(model,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#               ReLU-9           [-1, 64, 32, 32]               0
#     ResidualBlock-10           [-1, 64, 32, 32]               0
#            Conv2d-11           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-12           [-1, 64, 32, 32]             128
#              ReLU-13           [-1, 64, 32, 32]               0
#            Conv2d-14           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-15           [-1, 64, 32, 32]             128
#              ReLU-16           [-1, 64, 32, 32]               0
#     ResidualBlock-17           [-1, 64, 32, 32]               0
#            Conv2d-18          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-19          [-1, 128, 16, 16]             256
#              ReLU-20          [-1, 128, 16, 16]               0
#            Conv2d-21          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-22          [-1, 128, 16, 16]             256
#            Conv2d-23          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-24          [-1, 128, 16, 16]             256
#              ReLU-25          [-1, 128, 16, 16]               0
#     ResidualBlock-26          [-1, 128, 16, 16]               0
#            Conv2d-27          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-28          [-1, 128, 16, 16]             256
#              ReLU-29          [-1, 128, 16, 16]               0
#            Conv2d-30          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-31          [-1, 128, 16, 16]             256
#              ReLU-32          [-1, 128, 16, 16]               0
#     ResidualBlock-33          [-1, 128, 16, 16]               0
#            Conv2d-34            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#              ReLU-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-38            [-1, 256, 8, 8]             512
#            Conv2d-39            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-40            [-1, 256, 8, 8]             512
#              ReLU-41            [-1, 256, 8, 8]               0
#     ResidualBlock-42            [-1, 256, 8, 8]               0
#            Conv2d-43            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-44            [-1, 256, 8, 8]             512
#              ReLU-45            [-1, 256, 8, 8]               0
#            Conv2d-46            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-47            [-1, 256, 8, 8]             512
#              ReLU-48            [-1, 256, 8, 8]               0
#     ResidualBlock-49            [-1, 256, 8, 8]               0
#         AvgPool2d-50            [-1, 256, 1, 1]               0
#            Linear-51                   [-1, 10]           2,570
# ================================================================
# Total params: 2,777,674
# Trainable params: 2,777,674
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 14.50
# Params size (MB): 10.60
# Estimated Total Size (MB): 25.11
# ----------------------------------------------------------------

# %% [markdown]
# 3. Optimizer可以调SGD、ADAM等等

# %%
# loss function and optimizer
#criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9, weight_decay=1e-3)

# %%
#train
def train(model):
    model.train()
    train_loss=0
    train_acc=0
    for img,label in train_loader:
        img=img.to(device)
        label=label.to(device)
        #forward
        output=model(img)
        loss=criterion(output,label)
        #backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #calculate loss and acc
        train_loss+=loss.item()
        _, predicted=output.max(1)
        train_acc+=(predicted==label).sum().item()/len(predicted)
    return train_loss/len(train_loader),train_acc/len(train_loader)

# %%
def test(model):
    model.eval()
    with torch.no_grad():
        valid_acc=0
        for img,label in test_loader:
            img=img.to(device)
            label=label.to(device)
            output=model(img)
            _, predicted=output.max(1)
            valid_acc+=(predicted==label).sum().item()/len(output)
    return valid_acc/len(test_loader)

# %%
for batch_size in batch_sizes:
    print("Batch size: %d"%(batch_size))
    train_loader=torch.utils.data.DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
    test_loader=torch.utils.data.DataLoader(test_dataset,batch_size=batch_size,shuffle=False)
    model=ResNet(ResidualBlock,[2,2,2]).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=50)
    for i in range(epochs):
        train_loss, train_acc=train(model)
        test_acc=test(model)
        print("Epoch %d. Train Loss %.4f. Train Acc %.4f. Test Acc %.4f."%(i,train_loss,train_acc,test_acc))
        scheduler.step()
# Out:
# Batch size: 32
# Epoch 0. Train Loss 1.4754. Train Acc 0.4589. Test Acc 0.5893.
# Epoch 1. Train Loss 0.9641. Train Acc 0.6577. Test Acc 0.6951.
# Epoch 2. Train Loss 0.7557. Train Acc 0.7366. Test Acc 0.7561.
# Epoch 3. Train Loss 0.6386. Train Acc 0.7780. Test Acc 0.7790.
# Epoch 4. Train Loss 0.5705. Train Acc 0.8047. Test Acc 0.7976.
# Epoch 5. Train Loss 0.5221. Train Acc 0.8215. Test Acc 0.8095.
# Epoch 6. Train Loss 0.4798. Train Acc 0.8358. Test Acc 0.8236.
# Epoch 7. Train Loss 0.4516. Train Acc 0.8461. Test Acc 0.8434.
# Epoch 8. Train Loss 0.4241. Train Acc 0.8560. Test Acc 0.8343.
# Epoch 9. Train Loss 0.4076. Train Acc 0.8607. Test Acc 0.8509.
# Epoch 10. Train Loss 0.3897. Train Acc 0.8674. Test Acc 0.7969.
# Epoch 11. Train Loss 0.3752. Train Acc 0.8738. Test Acc 0.8405.
# Epoch 12. Train Loss 0.3564. Train Acc 0.8785. Test Acc 0.8540.
# Epoch 13. Train Loss 0.3476. Train Acc 0.8823. Test Acc 0.8609.
# Epoch 14. Train Loss 0.3368. Train Acc 0.8863. Test Acc 0.8684.
# Epoch 15. Train Loss 0.3226. Train Acc 0.8908. Test Acc 0.8715.
# Epoch 16. Train Loss 0.3128. Train Acc 0.8932. Test Acc 0.8682.
# Epoch 17. Train Loss 0.3020. Train Acc 0.8967. Test Acc 0.8616.
# Epoch 18. Train Loss 0.2936. Train Acc 0.9009. Test Acc 0.8758.
# Epoch 19. Train Loss 0.2768. Train Acc 0.9083. Test Acc 0.8711.
# Epoch 20. Train Loss 0.2654. Train Acc 0.9098. Test Acc 0.8640.
# Epoch 21. Train Loss 0.2550. Train Acc 0.9130. Test Acc 0.8784.
# Epoch 22. Train Loss 0.2434. Train Acc 0.9174. Test Acc 0.8867.
# Epoch 23. Train Loss 0.2314. Train Acc 0.9211. Test Acc 0.8993.
# Epoch 24. Train Loss 0.2221. Train Acc 0.9257. Test Acc 0.8988.
# Epoch 25. Train Loss 0.2091. Train Acc 0.9303. Test Acc 0.9068.
# Epoch 26. Train Loss 0.1991. Train Acc 0.9335. Test Acc 0.8887.
# Epoch 27. Train Loss 0.1841. Train Acc 0.9402. Test Acc 0.9098.
# Epoch 28. Train Loss 0.1713. Train Acc 0.9417. Test Acc 0.8983.
# Epoch 29. Train Loss 0.1576. Train Acc 0.9484. Test Acc 0.9080.
# Epoch 30. Train Loss 0.1476. Train Acc 0.9516. Test Acc 0.9075.
# Epoch 31. Train Loss 0.1330. Train Acc 0.9583. Test Acc 0.9171.
# Epoch 32. Train Loss 0.1168. Train Acc 0.9627. Test Acc 0.9165.
# Epoch 33. Train Loss 0.1049. Train Acc 0.9671. Test Acc 0.9176.
# Epoch 34. Train Loss 0.0907. Train Acc 0.9724. Test Acc 0.9260.
# Epoch 35. Train Loss 0.0798. Train Acc 0.9762. Test Acc 0.9292.
# Epoch 36. Train Loss 0.0661. Train Acc 0.9813. Test Acc 0.9308.
# Epoch 37. Train Loss 0.0580. Train Acc 0.9838. Test Acc 0.9303.
# Epoch 38. Train Loss 0.0462. Train Acc 0.9886. Test Acc 0.9373.
# Epoch 39. Train Loss 0.0380. Train Acc 0.9912. Test Acc 0.9387.
# Epoch 40. Train Loss 0.0312. Train Acc 0.9940. Test Acc 0.9373.
# Epoch 41. Train Loss 0.0256. Train Acc 0.9957. Test Acc 0.9378.
# Epoch 42. Train Loss 0.0228. Train Acc 0.9966. Test Acc 0.9397.
# Epoch 43. Train Loss 0.0212. Train Acc 0.9967. Test Acc 0.9417.
# Epoch 44. Train Loss 0.0179. Train Acc 0.9979. Test Acc 0.9431.
# Epoch 45. Train Loss 0.0170. Train Acc 0.9979. Test Acc 0.9434.
# Epoch 46. Train Loss 0.0157. Train Acc 0.9984. Test Acc 0.9444.
# Epoch 47. Train Loss 0.0154. Train Acc 0.9984. Test Acc 0.9430.
# Epoch 48. Train Loss 0.0148. Train Acc 0.9987. Test Acc 0.9444.
# Epoch 49. Train Loss 0.0140. Train Acc 0.9988. Test Acc 0.9449.
# Batch size: 64
# Epoch 0. Train Loss 1.4131. Train Acc 0.4806. Test Acc 0.5871.
# Epoch 1. Train Loss 0.9205. Train Acc 0.6712. Test Acc 0.6487.
# Epoch 2. Train Loss 0.7130. Train Acc 0.7510. Test Acc 0.7277.
# Epoch 3. Train Loss 0.6116. Train Acc 0.7882. Test Acc 0.7957.
# Epoch 4. Train Loss 0.5396. Train Acc 0.8151. Test Acc 0.8033.
# Epoch 5. Train Loss 0.4837. Train Acc 0.8311. Test Acc 0.8154.
# Epoch 6. Train Loss 0.4418. Train Acc 0.8481. Test Acc 0.8107.
# Epoch 7. Train Loss 0.4113. Train Acc 0.8607. Test Acc 0.8040.
# Epoch 8. Train Loss 0.3786. Train Acc 0.8720. Test Acc 0.8253.
# Epoch 9. Train Loss 0.3559. Train Acc 0.8776. Test Acc 0.8305.
# Epoch 10. Train Loss 0.3356. Train Acc 0.8852. Test Acc 0.8565.
# Epoch 11. Train Loss 0.3158. Train Acc 0.8928. Test Acc 0.8327.
# Epoch 12. Train Loss 0.2996. Train Acc 0.8984. Test Acc 0.8448.
# Epoch 13. Train Loss 0.2816. Train Acc 0.9039. Test Acc 0.8663.
# Epoch 14. Train Loss 0.2654. Train Acc 0.9096. Test Acc 0.8794.
# Epoch 15. Train Loss 0.2526. Train Acc 0.9148. Test Acc 0.8692.
# Epoch 16. Train Loss 0.2389. Train Acc 0.9194. Test Acc 0.8969.
# Epoch 17. Train Loss 0.2254. Train Acc 0.9245. Test Acc 0.8619.
# Epoch 18. Train Loss 0.2172. Train Acc 0.9275. Test Acc 0.8765.
# Epoch 19. Train Loss 0.2045. Train Acc 0.9305. Test Acc 0.8785.
# Epoch 20. Train Loss 0.1923. Train Acc 0.9351. Test Acc 0.8964.
# Epoch 21. Train Loss 0.1788. Train Acc 0.9394. Test Acc 0.8928.
# Epoch 22. Train Loss 0.1681. Train Acc 0.9447. Test Acc 0.8860.
# Epoch 23. Train Loss 0.1572. Train Acc 0.9479. Test Acc 0.9036.
# Epoch 24. Train Loss 0.1538. Train Acc 0.9483. Test Acc 0.8992.
# Epoch 25. Train Loss 0.1381. Train Acc 0.9546. Test Acc 0.8984.
# Epoch 26. Train Loss 0.1254. Train Acc 0.9588. Test Acc 0.8992.
# Epoch 27. Train Loss 0.1138. Train Acc 0.9640. Test Acc 0.8971.
# Epoch 28. Train Loss 0.1033. Train Acc 0.9672. Test Acc 0.9151.
# Epoch 29. Train Loss 0.0923. Train Acc 0.9717. Test Acc 0.9070.
# Epoch 30. Train Loss 0.0862. Train Acc 0.9732. Test Acc 0.9176.
# Epoch 31. Train Loss 0.0708. Train Acc 0.9797. Test Acc 0.9201.
# Epoch 32. Train Loss 0.0631. Train Acc 0.9824. Test Acc 0.9189.
# Epoch 33. Train Loss 0.0529. Train Acc 0.9854. Test Acc 0.9214.
# Epoch 34. Train Loss 0.0437. Train Acc 0.9889. Test Acc 0.9254.
# Epoch 35. Train Loss 0.0375. Train Acc 0.9912. Test Acc 0.9284.
# Epoch 36. Train Loss 0.0303. Train Acc 0.9938. Test Acc 0.9306.
# Epoch 37. Train Loss 0.0251. Train Acc 0.9954. Test Acc 0.9310.
# Epoch 38. Train Loss 0.0221. Train Acc 0.9961. Test Acc 0.9351.
# Epoch 39. Train Loss 0.0192. Train Acc 0.9972. Test Acc 0.9340.
# Epoch 40. Train Loss 0.0162. Train Acc 0.9981. Test Acc 0.9363.
# Epoch 41. Train Loss 0.0155. Train Acc 0.9980. Test Acc 0.9354.
# Epoch 42. Train Loss 0.0135. Train Acc 0.9987. Test Acc 0.9383.
# Epoch 43. Train Loss 0.0136. Train Acc 0.9986. Test Acc 0.9384.
# Epoch 44. Train Loss 0.0121. Train Acc 0.9990. Test Acc 0.9383.
# Epoch 45. Train Loss 0.0113. Train Acc 0.9991. Test Acc 0.9383.
# Epoch 46. Train Loss 0.0115. Train Acc 0.9991. Test Acc 0.9379.
# Epoch 47. Train Loss 0.0112. Train Acc 0.9991. Test Acc 0.9384.
# Epoch 48. Train Loss 0.0107. Train Acc 0.9994. Test Acc 0.9383.
# Epoch 49. Train Loss 0.0106. Train Acc 0.9993. Test Acc 0.9387.
# Batch size: 128
# Epoch 0. Train Loss 1.4114. Train Acc 0.4800. Test Acc 0.5831.
# Epoch 1. Train Loss 0.9495. Train Acc 0.6626. Test Acc 0.6237.
# Epoch 2. Train Loss 0.7475. Train Acc 0.7354. Test Acc 0.7201.
# Epoch 3. Train Loss 0.6273. Train Acc 0.7820. Test Acc 0.7251.
# Epoch 4. Train Loss 0.5532. Train Acc 0.8089. Test Acc 0.7285.
# Epoch 5. Train Loss 0.4981. Train Acc 0.8286. Test Acc 0.7447.
# Epoch 6. Train Loss 0.4459. Train Acc 0.8462. Test Acc 0.8236.
# Epoch 7. Train Loss 0.4111. Train Acc 0.8584. Test Acc 0.8104.
# Epoch 8. Train Loss 0.3802. Train Acc 0.8682. Test Acc 0.8293.
# Epoch 9. Train Loss 0.3525. Train Acc 0.8787. Test Acc 0.8318.
# Epoch 10. Train Loss 0.3305. Train Acc 0.8863. Test Acc 0.8122.
# Epoch 11. Train Loss 0.3067. Train Acc 0.8952. Test Acc 0.8556.
# Epoch 12. Train Loss 0.2869. Train Acc 0.9008. Test Acc 0.8286.
# Epoch 13. Train Loss 0.2676. Train Acc 0.9084. Test Acc 0.8469.
# Epoch 14. Train Loss 0.2522. Train Acc 0.9127. Test Acc 0.8673.
# Epoch 15. Train Loss 0.2379. Train Acc 0.9189. Test Acc 0.8737.
# Epoch 16. Train Loss 0.2238. Train Acc 0.9230. Test Acc 0.8779.
# Epoch 17. Train Loss 0.2066. Train Acc 0.9300. Test Acc 0.8784.
# Epoch 18. Train Loss 0.2004. Train Acc 0.9320. Test Acc 0.8760.
# Epoch 19. Train Loss 0.1812. Train Acc 0.9393. Test Acc 0.8523.
# Epoch 20. Train Loss 0.1720. Train Acc 0.9418. Test Acc 0.8827.
# Epoch 21. Train Loss 0.1597. Train Acc 0.9461. Test Acc 0.9025.
# Epoch 22. Train Loss 0.1464. Train Acc 0.9519. Test Acc 0.8758.
# Epoch 23. Train Loss 0.1365. Train Acc 0.9547. Test Acc 0.8805.
# Epoch 24. Train Loss 0.1252. Train Acc 0.9594. Test Acc 0.9017.
# Epoch 25. Train Loss 0.1113. Train Acc 0.9643. Test Acc 0.9080.
# Epoch 26. Train Loss 0.1029. Train Acc 0.9675. Test Acc 0.8913.
# Epoch 27. Train Loss 0.0939. Train Acc 0.9708. Test Acc 0.8882.
# Epoch 28. Train Loss 0.0822. Train Acc 0.9746. Test Acc 0.9109.
# Epoch 29. Train Loss 0.0780. Train Acc 0.9762. Test Acc 0.9087.
# Epoch 30. Train Loss 0.0671. Train Acc 0.9802. Test Acc 0.9137.
# Epoch 31. Train Loss 0.0584. Train Acc 0.9836. Test Acc 0.9174.
# Epoch 32. Train Loss 0.0487. Train Acc 0.9868. Test Acc 0.9197.
# Epoch 33. Train Loss 0.0434. Train Acc 0.9891. Test Acc 0.9224.
# Epoch 34. Train Loss 0.0358. Train Acc 0.9923. Test Acc 0.9226.
# Epoch 35. Train Loss 0.0321. Train Acc 0.9937. Test Acc 0.9260.
# Epoch 36. Train Loss 0.0280. Train Acc 0.9947. Test Acc 0.9272.
# Epoch 37. Train Loss 0.0237. Train Acc 0.9963. Test Acc 0.9233.
# Epoch 38. Train Loss 0.0213. Train Acc 0.9968. Test Acc 0.9299.
# Epoch 39. Train Loss 0.0188. Train Acc 0.9978. Test Acc 0.9288.
# Epoch 40. Train Loss 0.0182. Train Acc 0.9978. Test Acc 0.9301.
# Epoch 41. Train Loss 0.0166. Train Acc 0.9983. Test Acc 0.9319.
# Epoch 42. Train Loss 0.0153. Train Acc 0.9988. Test Acc 0.9312.
# Epoch 43. Train Loss 0.0147. Train Acc 0.9987. Test Acc 0.9323.
# Epoch 44. Train Loss 0.0142. Train Acc 0.9987. Test Acc 0.9330.
# Epoch 45. Train Loss 0.0138. Train Acc 0.9988. Test Acc 0.9321.
# Epoch 46. Train Loss 0.0137. Train Acc 0.9989. Test Acc 0.9318.
# Epoch 47. Train Loss 0.0130. Train Acc 0.9991. Test Acc 0.9328.
# Epoch 48. Train Loss 0.0130. Train Acc 0.9990. Test Acc 0.9321.
# Epoch 49. Train Loss 0.0130. Train Acc 0.9991. Test Acc 0.9326.
# Batch size: 256
# Epoch 0. Train Loss 1.4716. Train Acc 0.4585. Test Acc 0.4888.
# Epoch 1. Train Loss 1.0036. Train Acc 0.6441. Test Acc 0.6290.
# Epoch 2. Train Loss 0.7989. Train Acc 0.7166. Test Acc 0.7186.
# Epoch 3. Train Loss 0.6653. Train Acc 0.7686. Test Acc 0.6562.
# Epoch 4. Train Loss 0.5907. Train Acc 0.7960. Test Acc 0.6251.
# Epoch 5. Train Loss 0.5246. Train Acc 0.8198. Test Acc 0.7783.
# Epoch 6. Train Loss 0.4733. Train Acc 0.8375. Test Acc 0.8073.
# Epoch 7. Train Loss 0.4272. Train Acc 0.8531. Test Acc 0.7735.
# Epoch 8. Train Loss 0.3966. Train Acc 0.8637. Test Acc 0.8259.
# Epoch 9. Train Loss 0.3666. Train Acc 0.8733. Test Acc 0.8123.
# Epoch 10. Train Loss 0.3454. Train Acc 0.8823. Test Acc 0.8162.
# Epoch 11. Train Loss 0.3209. Train Acc 0.8890. Test Acc 0.8444.
# Epoch 12. Train Loss 0.2977. Train Acc 0.8980. Test Acc 0.8296.
# Epoch 13. Train Loss 0.2846. Train Acc 0.9022. Test Acc 0.8142.
# Epoch 14. Train Loss 0.2597. Train Acc 0.9104. Test Acc 0.8334.
# Epoch 15. Train Loss 0.2453. Train Acc 0.9159. Test Acc 0.7631.
# Epoch 16. Train Loss 0.2328. Train Acc 0.9208. Test Acc 0.8548.
# Epoch 17. Train Loss 0.2155. Train Acc 0.9267. Test Acc 0.8540.
# Epoch 18. Train Loss 0.2075. Train Acc 0.9293. Test Acc 0.8494.
# Epoch 19. Train Loss 0.1913. Train Acc 0.9331. Test Acc 0.8392.
# Epoch 20. Train Loss 0.1799. Train Acc 0.9387. Test Acc 0.8511.
# Epoch 21. Train Loss 0.1642. Train Acc 0.9445. Test Acc 0.8748.
# Epoch 22. Train Loss 0.1523. Train Acc 0.9477. Test Acc 0.8435.
# Epoch 23. Train Loss 0.1430. Train Acc 0.9518. Test Acc 0.8937.
# Epoch 24. Train Loss 0.1303. Train Acc 0.9568. Test Acc 0.8711.
# Epoch 25. Train Loss 0.1253. Train Acc 0.9586. Test Acc 0.8768.
# Epoch 26. Train Loss 0.1128. Train Acc 0.9634. Test Acc 0.8902.
# Epoch 27. Train Loss 0.1023. Train Acc 0.9674. Test Acc 0.8938.
# Epoch 28. Train Loss 0.0914. Train Acc 0.9720. Test Acc 0.9039.
# Epoch 29. Train Loss 0.0823. Train Acc 0.9744. Test Acc 0.8964.
# Epoch 30. Train Loss 0.0741. Train Acc 0.9780. Test Acc 0.8999.
# Epoch 31. Train Loss 0.0663. Train Acc 0.9808. Test Acc 0.9108.
# Epoch 32. Train Loss 0.0604. Train Acc 0.9829. Test Acc 0.9022.
# Epoch 33. Train Loss 0.0529. Train Acc 0.9858. Test Acc 0.9046.
# Epoch 34. Train Loss 0.0473. Train Acc 0.9882. Test Acc 0.9144.
# Epoch 35. Train Loss 0.0415. Train Acc 0.9903. Test Acc 0.9163.
# Epoch 36. Train Loss 0.0378. Train Acc 0.9921. Test Acc 0.9128.
# Epoch 37. Train Loss 0.0342. Train Acc 0.9933. Test Acc 0.9174.
# Epoch 38. Train Loss 0.0308. Train Acc 0.9943. Test Acc 0.9186.
# Epoch 39. Train Loss 0.0277. Train Acc 0.9958. Test Acc 0.9206.
# Epoch 40. Train Loss 0.0269. Train Acc 0.9956. Test Acc 0.9201.
# Epoch 41. Train Loss 0.0249. Train Acc 0.9963. Test Acc 0.9220.
# Epoch 42. Train Loss 0.0236. Train Acc 0.9967. Test Acc 0.9219.
# Epoch 43. Train Loss 0.0225. Train Acc 0.9971. Test Acc 0.9218.
# Epoch 44. Train Loss 0.0219. Train Acc 0.9971. Test Acc 0.9231.
# Epoch 45. Train Loss 0.0210. Train Acc 0.9972. Test Acc 0.9224.
# Epoch 46. Train Loss 0.0206. Train Acc 0.9976. Test Acc 0.9226.
# Epoch 47. Train Loss 0.0206. Train Acc 0.9975. Test Acc 0.9225.
# Epoch 48. Train Loss 0.0196. Train Acc 0.9981. Test Acc 0.9222.
# Epoch 49. Train Loss 0.0199. Train Acc 0.9979. Test Acc 0.9231.
