# %%
# %pip install torch
# %pip install torchvision
# %pip install torchsummary
# Out:
# Requirement already satisfied: torch in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.13.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (4.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: numpy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.23.4)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: torch==1.13.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.13.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (4.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (8.5.0.96)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (0.37.1)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (65.5.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (1.26.12)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchsummary in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchsummary import summary

# %%
#choose device
if torch.cuda.is_available():
    device=torch.device('cuda')
else:
    device=torch.device('cpu')

# %% [markdown]
# 1. Epoch, batchsize, learning rate都能调整

# %%
epochs=50
batch_size=64
learning_rates=[0.01,0.005,0.003,0.001]

# %% [markdown]
# 2. transform的方法也能调整

# %%
#define transform
train_transform=transforms.Compose(
    [transforms.Pad(4),
     transforms.RandomCrop(32),
     transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
     transforms.Normalize(mean=[0.485,0.456,0.406],
                          std=[0.229,0.224,0.225])])
valid_transform=transforms.Compose(
    [
     transforms.ToTensor(),
     transforms.Normalize(mean=[0.485,0.456,0.406],
                          std=[0.229,0.224,0.225])])

# %%
# download cifar-10 dataset
train_dataset=torchvision.datasets.CIFAR10(root='../data/',
                                           train=True,
                                           transform=train_transform,
                                           download=True)
test_dataset=torchvision.datasets.CIFAR10(root='../data/',
                                           train=False,
                                           transform=valid_transform,
                                           download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# define data loader
train_loader=torch.utils.data.DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
test_loader=torch.utils.data.DataLoader(test_dataset,batch_size=batch_size,shuffle=False)

# %%
# residual block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1=nn.Conv2d(in_channels=in_channels,out_channels=out_channels,stride=stride,kernel_size=3,padding=1,bias=False)
        self.bn1=nn.BatchNorm2d(out_channels)
        self.relu=nn.ReLU(inplace=True)
        self.conv2=nn.Conv2d(in_channels=out_channels,out_channels=out_channels,stride=1,kernel_size=3,padding=1,bias=False)
        self.bn2=nn.BatchNorm2d(out_channels)
        self.downsample=nn.Sequential()
        if (stride!=1) or(in_channels!=out_channels):
            self.downsample=nn.Sequential(
                nn.Conv2d(in_channels=in_channels,out_channels=out_channels,stride=stride,kernel_size=1,bias=False),
                nn.BatchNorm2d(out_channels))
    def forward(self,x):
        out=self.conv1(x)
        out=self.bn1(out)
        out=self.relu(out)
        out=self.conv2(out)
        out=self.bn2(out)
        out+=self.downsample(x)
        out=self.relu(out)
        return out

# %%
# 4-layer ResNet
class ResNet(nn.Module):
    def __init__(self,block,layers,num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels=64                                                  # 64 can be modified
        self.conv=nn.Conv2d(in_channels=3,out_channels=64,stride=1,kernel_size=3,padding=1,bias=False)
        self.bn=nn.BatchNorm2d(64)
        self.relu=nn.ReLU(inplace=True)
        self.layer1=self.make_layer(block, 64,layers[0], stride=1)        # 64 can be modified
        self.layer2=self.make_layer(block, 128, layers[1], stride=2)      # 128 can be modified
        self.layer3=self.make_layer(block, 256, layers[2], stride=2)      # 256 can be modified
        #self.layer4=self.make_layer(block, 512, layers[3], stride=2)      # 512 can be modified
        self.avg_pool=nn.AvgPool2d(8)                                        # 4 can be modified
        self.fc=nn.Linear(256,10) 
        
    def make_layer(self,block,out_channels,blocks, stride):
        layers=[]
        layers.append(block(self.in_channels,out_channels,stride))
        self.in_channels=out_channels
        for i in range(1,blocks):
            layers.append(block(out_channels,out_channels,stride=1))
        return nn.Sequential(*layers)
    
    def forward(self,x):
        out=self.conv(x)
        out=self.bn(out)
        out=self.relu(out)
        out=self.layer1(out)
        out=self.layer2(out)
        out=self.layer3(out)
        #out=self.layer4(out)
        out=self.avg_pool(out)
        out=out.view(out.size(0),-1)
        out=self.fc(out)
        return out

# %%
model=ResNet(ResidualBlock,[2,2,2]).to(device)
summary(model,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#               ReLU-9           [-1, 64, 32, 32]               0
#     ResidualBlock-10           [-1, 64, 32, 32]               0
#            Conv2d-11           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-12           [-1, 64, 32, 32]             128
#              ReLU-13           [-1, 64, 32, 32]               0
#            Conv2d-14           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-15           [-1, 64, 32, 32]             128
#              ReLU-16           [-1, 64, 32, 32]               0
#     ResidualBlock-17           [-1, 64, 32, 32]               0
#            Conv2d-18          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-19          [-1, 128, 16, 16]             256
#              ReLU-20          [-1, 128, 16, 16]               0
#            Conv2d-21          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-22          [-1, 128, 16, 16]             256
#            Conv2d-23          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-24          [-1, 128, 16, 16]             256
#              ReLU-25          [-1, 128, 16, 16]               0
#     ResidualBlock-26          [-1, 128, 16, 16]               0
#            Conv2d-27          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-28          [-1, 128, 16, 16]             256
#              ReLU-29          [-1, 128, 16, 16]               0
#            Conv2d-30          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-31          [-1, 128, 16, 16]             256
#              ReLU-32          [-1, 128, 16, 16]               0
#     ResidualBlock-33          [-1, 128, 16, 16]               0
#            Conv2d-34            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#              ReLU-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-38            [-1, 256, 8, 8]             512
#            Conv2d-39            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-40            [-1, 256, 8, 8]             512
#              ReLU-41            [-1, 256, 8, 8]               0
#     ResidualBlock-42            [-1, 256, 8, 8]               0
#            Conv2d-43            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-44            [-1, 256, 8, 8]             512
#              ReLU-45            [-1, 256, 8, 8]               0
#            Conv2d-46            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-47            [-1, 256, 8, 8]             512
#              ReLU-48            [-1, 256, 8, 8]               0
#     ResidualBlock-49            [-1, 256, 8, 8]               0
#         AvgPool2d-50            [-1, 256, 1, 1]               0
#            Linear-51                   [-1, 10]           2,570
# ================================================================
# Total params: 2,777,674
# Trainable params: 2,777,674
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 14.50
# Params size (MB): 10.60
# Estimated Total Size (MB): 25.11
# ----------------------------------------------------------------

# %% [markdown]
# 3. Optimizer可以调SGD、ADAM等等

# %%
# loss function and optimizer
criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9, weight_decay=1e-3)

# %%
#train
def train(model):
    model.train()
    train_loss=0
    train_acc=0
    for img,label in train_loader:
        img=img.to(device)
        label=label.to(device)
        #forward
        output=model(img)
        loss=criterion(output,label)
        #backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #calculate loss and acc
        train_loss+=loss.item()
        _, predicted=output.max(1)
        train_acc+=(predicted==label).sum().item()/len(predicted)
    return train_loss/len(train_loader),train_acc/len(train_loader)

# %%
def test(model):
    model.eval()
    with torch.no_grad():
        valid_acc=0
        for img,label in test_loader:
            img=img.to(device)
            label=label.to(device)
            output=model(img)
            _, predicted=output.max(1)
            valid_acc+=(predicted==label).sum().item()/len(output)
    return valid_acc/len(test_loader)

# %%
for learning_rate in learning_rates:
    print("Learning rate: %f"%(learning_rate))
    model=ResNet(ResidualBlock,[2,2,2]).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9, weight_decay=1e-3)
    for i in range(epochs):
        train_loss, train_acc=train(model)
        test_acc=test(model)
        print("Epoch %d. Train Loss %.4f. Train Acc %.4f. Test Acc %.4f."%(i,train_loss,train_acc,test_acc))
# Out:
# Learning rate: 0.010000
# Epoch 0. Train Loss 1.4026. Train Acc 0.4848. Test Acc 0.5746.
# Epoch 1. Train Loss 0.9012. Train Acc 0.6816. Test Acc 0.6711.
# Epoch 2. Train Loss 0.7103. Train Acc 0.7525. Test Acc 0.7369.
# Epoch 3. Train Loss 0.6023. Train Acc 0.7914. Test Acc 0.7948.
# Epoch 4. Train Loss 0.5376. Train Acc 0.8138. Test Acc 0.8017.
# Epoch 5. Train Loss 0.4794. Train Acc 0.8354. Test Acc 0.7912.
# Epoch 6. Train Loss 0.4486. Train Acc 0.8449. Test Acc 0.7610.
# Epoch 7. Train Loss 0.4222. Train Acc 0.8560. Test Acc 0.8357.
# Epoch 8. Train Loss 0.3870. Train Acc 0.8688. Test Acc 0.8406.
# Epoch 9. Train Loss 0.3643. Train Acc 0.8756. Test Acc 0.8606.
# Epoch 10. Train Loss 0.3458. Train Acc 0.8820. Test Acc 0.8658.
# Epoch 11. Train Loss 0.3306. Train Acc 0.8879. Test Acc 0.8526.
# Epoch 12. Train Loss 0.3158. Train Acc 0.8928. Test Acc 0.8522.
# Epoch 13. Train Loss 0.3002. Train Acc 0.8978. Test Acc 0.8546.
# Epoch 14. Train Loss 0.2865. Train Acc 0.9032. Test Acc 0.8634.
# Epoch 15. Train Loss 0.2770. Train Acc 0.9058. Test Acc 0.8312.
# Epoch 16. Train Loss 0.2673. Train Acc 0.9087. Test Acc 0.8746.
# Epoch 17. Train Loss 0.2650. Train Acc 0.9095. Test Acc 0.8447.
# Epoch 18. Train Loss 0.2550. Train Acc 0.9132. Test Acc 0.8816.
# Epoch 19. Train Loss 0.2536. Train Acc 0.9146. Test Acc 0.8798.
# Epoch 20. Train Loss 0.2413. Train Acc 0.9181. Test Acc 0.8839.
# Epoch 21. Train Loss 0.2416. Train Acc 0.9181. Test Acc 0.8702.
# Epoch 22. Train Loss 0.2366. Train Acc 0.9201. Test Acc 0.8846.
# Epoch 23. Train Loss 0.2316. Train Acc 0.9224. Test Acc 0.8206.
# Epoch 24. Train Loss 0.2293. Train Acc 0.9229. Test Acc 0.8877.
# Epoch 25. Train Loss 0.2271. Train Acc 0.9232. Test Acc 0.8808.
# Epoch 26. Train Loss 0.2229. Train Acc 0.9240. Test Acc 0.8745.
# Epoch 27. Train Loss 0.2183. Train Acc 0.9259. Test Acc 0.8812.
# Epoch 28. Train Loss 0.2133. Train Acc 0.9277. Test Acc 0.8893.
# Epoch 29. Train Loss 0.2128. Train Acc 0.9289. Test Acc 0.8724.
# Epoch 30. Train Loss 0.2069. Train Acc 0.9302. Test Acc 0.8651.
# Epoch 31. Train Loss 0.2042. Train Acc 0.9320. Test Acc 0.8902.
# Epoch 32. Train Loss 0.2043. Train Acc 0.9316. Test Acc 0.8753.
# Epoch 33. Train Loss 0.2013. Train Acc 0.9321. Test Acc 0.8873.
# Epoch 34. Train Loss 0.1988. Train Acc 0.9320. Test Acc 0.8938.
# Epoch 35. Train Loss 0.1971. Train Acc 0.9342. Test Acc 0.8897.
# Epoch 36. Train Loss 0.1981. Train Acc 0.9324. Test Acc 0.8666.
# Epoch 37. Train Loss 0.1958. Train Acc 0.9345. Test Acc 0.8989.
# Epoch 38. Train Loss 0.1923. Train Acc 0.9359. Test Acc 0.8837.
# Epoch 39. Train Loss 0.1866. Train Acc 0.9385. Test Acc 0.8762.
# Epoch 40. Train Loss 0.1884. Train Acc 0.9372. Test Acc 0.8782.
# Epoch 41. Train Loss 0.1800. Train Acc 0.9395. Test Acc 0.8734.
# Epoch 42. Train Loss 0.1880. Train Acc 0.9352. Test Acc 0.8888.
# Epoch 43. Train Loss 0.1840. Train Acc 0.9393. Test Acc 0.8912.
# Epoch 44. Train Loss 0.1860. Train Acc 0.9384. Test Acc 0.8961.
# Epoch 45. Train Loss 0.1770. Train Acc 0.9407. Test Acc 0.8848.
# Epoch 46. Train Loss 0.1780. Train Acc 0.9396. Test Acc 0.8755.
# Epoch 47. Train Loss 0.1740. Train Acc 0.9423. Test Acc 0.8940.
# Epoch 48. Train Loss 0.1799. Train Acc 0.9387. Test Acc 0.8952.
# Epoch 49. Train Loss 0.1760. Train Acc 0.9418. Test Acc 0.8868.
# Learning rate: 0.005000
# Epoch 0. Train Loss 1.3664. Train Acc 0.4952. Test Acc 0.5679.
# Epoch 1. Train Loss 0.9320. Train Acc 0.6697. Test Acc 0.6670.
# Epoch 2. Train Loss 0.7361. Train Acc 0.7426. Test Acc 0.7165.
# Epoch 3. Train Loss 0.6222. Train Acc 0.7852. Test Acc 0.7794.
# Epoch 4. Train Loss 0.5479. Train Acc 0.8102. Test Acc 0.7974.
# Epoch 5. Train Loss 0.4933. Train Acc 0.8317. Test Acc 0.8038.
# Epoch 6. Train Loss 0.4513. Train Acc 0.8420. Test Acc 0.8286.
# Epoch 7. Train Loss 0.4152. Train Acc 0.8567. Test Acc 0.8145.
# Epoch 8. Train Loss 0.3828. Train Acc 0.8677. Test Acc 0.8599.
# Epoch 9. Train Loss 0.3624. Train Acc 0.8764. Test Acc 0.8343.
# Epoch 10. Train Loss 0.3341. Train Acc 0.8858. Test Acc 0.8608.
# Epoch 11. Train Loss 0.3238. Train Acc 0.8876. Test Acc 0.8527.
# Epoch 12. Train Loss 0.3073. Train Acc 0.8937. Test Acc 0.8090.
# Epoch 13. Train Loss 0.2855. Train Acc 0.9021. Test Acc 0.8680.
# Epoch 14. Train Loss 0.2729. Train Acc 0.9067. Test Acc 0.8678.
# Epoch 15. Train Loss 0.2611. Train Acc 0.9112. Test Acc 0.8710.
# Epoch 16. Train Loss 0.2481. Train Acc 0.9163. Test Acc 0.8507.
# Epoch 17. Train Loss 0.2420. Train Acc 0.9184. Test Acc 0.8706.
# Epoch 18. Train Loss 0.2301. Train Acc 0.9233. Test Acc 0.8735.
# Epoch 19. Train Loss 0.2232. Train Acc 0.9236. Test Acc 0.8819.
# Epoch 20. Train Loss 0.2138. Train Acc 0.9266. Test Acc 0.8823.
# Epoch 21. Train Loss 0.1998. Train Acc 0.9320. Test Acc 0.8906.
# Epoch 22. Train Loss 0.1976. Train Acc 0.9332. Test Acc 0.8808.
# Epoch 23. Train Loss 0.1957. Train Acc 0.9327. Test Acc 0.8918.
# Epoch 24. Train Loss 0.1808. Train Acc 0.9388. Test Acc 0.8883.
# Epoch 25. Train Loss 0.1789. Train Acc 0.9399. Test Acc 0.8851.
# Epoch 26. Train Loss 0.1750. Train Acc 0.9413. Test Acc 0.8622.
# Epoch 27. Train Loss 0.1711. Train Acc 0.9413. Test Acc 0.8963.
# Epoch 28. Train Loss 0.1656. Train Acc 0.9456. Test Acc 0.8959.
# Epoch 29. Train Loss 0.1615. Train Acc 0.9456. Test Acc 0.8905.
# Epoch 30. Train Loss 0.1571. Train Acc 0.9466. Test Acc 0.8726.
# Epoch 31. Train Loss 0.1480. Train Acc 0.9504. Test Acc 0.8862.
# Epoch 32. Train Loss 0.1469. Train Acc 0.9511. Test Acc 0.8947.
# Epoch 33. Train Loss 0.1499. Train Acc 0.9497. Test Acc 0.8928.
# Epoch 34. Train Loss 0.1411. Train Acc 0.9533. Test Acc 0.8973.
# Epoch 35. Train Loss 0.1379. Train Acc 0.9546. Test Acc 0.9079.
# Epoch 36. Train Loss 0.1366. Train Acc 0.9556. Test Acc 0.9021.
# Epoch 37. Train Loss 0.1348. Train Acc 0.9558. Test Acc 0.8962.
# Epoch 38. Train Loss 0.1287. Train Acc 0.9579. Test Acc 0.9069.
# Epoch 39. Train Loss 0.1296. Train Acc 0.9569. Test Acc 0.8995.
# Epoch 40. Train Loss 0.1265. Train Acc 0.9584. Test Acc 0.9094.
# Epoch 41. Train Loss 0.1334. Train Acc 0.9558. Test Acc 0.8982.
# Epoch 42. Train Loss 0.1277. Train Acc 0.9582. Test Acc 0.9045.
# Epoch 43. Train Loss 0.1273. Train Acc 0.9575. Test Acc 0.8886.
# Epoch 44. Train Loss 0.1243. Train Acc 0.9591. Test Acc 0.9002.
# Epoch 45. Train Loss 0.1244. Train Acc 0.9584. Test Acc 0.8628.
# Epoch 46. Train Loss 0.1202. Train Acc 0.9608. Test Acc 0.9025.
# Epoch 47. Train Loss 0.1281. Train Acc 0.9579. Test Acc 0.9008.
# Epoch 48. Train Loss 0.1238. Train Acc 0.9595. Test Acc 0.8894.
# Epoch 49. Train Loss 0.1207. Train Acc 0.9601. Test Acc 0.9050.
# Learning rate: 0.003000
# Epoch 0. Train Loss 1.3826. Train Acc 0.4929. Test Acc 0.5613.
# Epoch 1. Train Loss 0.9422. Train Acc 0.6646. Test Acc 0.5827.
# Epoch 2. Train Loss 0.7507. Train Acc 0.7371. Test Acc 0.7255.
# Epoch 3. Train Loss 0.6384. Train Acc 0.7795. Test Acc 0.7579.
# Epoch 4. Train Loss 0.5543. Train Acc 0.8069. Test Acc 0.7845.
# Epoch 5. Train Loss 0.5028. Train Acc 0.8269. Test Acc 0.7878.
# Epoch 6. Train Loss 0.4599. Train Acc 0.8423. Test Acc 0.8052.
# Epoch 7. Train Loss 0.4243. Train Acc 0.8537. Test Acc 0.8039.
# Epoch 8. Train Loss 0.3958. Train Acc 0.8642. Test Acc 0.8433.
# Epoch 9. Train Loss 0.3694. Train Acc 0.8743. Test Acc 0.8188.
# Epoch 10. Train Loss 0.3475. Train Acc 0.8806. Test Acc 0.8249.
# Epoch 11. Train Loss 0.3271. Train Acc 0.8873. Test Acc 0.8569.
# Epoch 12. Train Loss 0.3088. Train Acc 0.8938. Test Acc 0.8472.
# Epoch 13. Train Loss 0.2919. Train Acc 0.8989. Test Acc 0.8382.
# Epoch 14. Train Loss 0.2767. Train Acc 0.9041. Test Acc 0.8535.
# Epoch 15. Train Loss 0.2629. Train Acc 0.9103. Test Acc 0.8488.
# Epoch 16. Train Loss 0.2536. Train Acc 0.9136. Test Acc 0.8475.
# Epoch 17. Train Loss 0.2419. Train Acc 0.9174. Test Acc 0.8713.
# Epoch 18. Train Loss 0.2304. Train Acc 0.9218. Test Acc 0.8687.
# Epoch 19. Train Loss 0.2208. Train Acc 0.9248. Test Acc 0.8869.
# Epoch 20. Train Loss 0.2090. Train Acc 0.9283. Test Acc 0.8377.
# Epoch 21. Train Loss 0.2026. Train Acc 0.9305. Test Acc 0.8676.
# Epoch 22. Train Loss 0.1926. Train Acc 0.9354. Test Acc 0.8661.
# Epoch 23. Train Loss 0.1888. Train Acc 0.9350. Test Acc 0.8765.
# Epoch 24. Train Loss 0.1799. Train Acc 0.9386. Test Acc 0.8847.
# Epoch 25. Train Loss 0.1719. Train Acc 0.9414. Test Acc 0.8840.
# Epoch 26. Train Loss 0.1688. Train Acc 0.9433. Test Acc 0.8904.
# Epoch 27. Train Loss 0.1638. Train Acc 0.9440. Test Acc 0.8922.
# Epoch 28. Train Loss 0.1538. Train Acc 0.9485. Test Acc 0.8832.
# Epoch 29. Train Loss 0.1517. Train Acc 0.9492. Test Acc 0.8956.
# Epoch 30. Train Loss 0.1445. Train Acc 0.9515. Test Acc 0.8987.
# Epoch 31. Train Loss 0.1358. Train Acc 0.9551. Test Acc 0.8867.
# Epoch 32. Train Loss 0.1343. Train Acc 0.9554. Test Acc 0.8893.
# Epoch 33. Train Loss 0.1330. Train Acc 0.9569. Test Acc 0.9070.
# Epoch 34. Train Loss 0.1286. Train Acc 0.9576. Test Acc 0.8921.
# Epoch 35. Train Loss 0.1250. Train Acc 0.9584. Test Acc 0.8884.
# Epoch 36. Train Loss 0.1183. Train Acc 0.9614. Test Acc 0.8988.
# Epoch 37. Train Loss 0.1180. Train Acc 0.9619. Test Acc 0.8939.
# Epoch 38. Train Loss 0.1169. Train Acc 0.9616. Test Acc 0.8973.
# Epoch 39. Train Loss 0.1120. Train Acc 0.9635. Test Acc 0.8885.
# Epoch 40. Train Loss 0.1101. Train Acc 0.9638. Test Acc 0.8836.
# Epoch 41. Train Loss 0.1076. Train Acc 0.9651. Test Acc 0.8893.
# Epoch 42. Train Loss 0.1043. Train Acc 0.9668. Test Acc 0.9105.
# Epoch 43. Train Loss 0.0983. Train Acc 0.9680. Test Acc 0.8997.
# Epoch 44. Train Loss 0.0995. Train Acc 0.9677. Test Acc 0.8992.
# Epoch 45. Train Loss 0.0928. Train Acc 0.9698. Test Acc 0.8992.
# Epoch 46. Train Loss 0.0922. Train Acc 0.9709. Test Acc 0.8895.
# Epoch 47. Train Loss 0.0895. Train Acc 0.9723. Test Acc 0.9062.
# Epoch 48. Train Loss 0.0933. Train Acc 0.9705. Test Acc 0.8899.
# Epoch 49. Train Loss 0.0929. Train Acc 0.9702. Test Acc 0.9043.
# Learning rate: 0.001000
# Epoch 0. Train Loss 1.5060. Train Acc 0.4480. Test Acc 0.5367.
# Epoch 1. Train Loss 1.0856. Train Acc 0.6114. Test Acc 0.6349.
# Epoch 2. Train Loss 0.9021. Train Acc 0.6819. Test Acc 0.6535.
# Epoch 3. Train Loss 0.7793. Train Acc 0.7257. Test Acc 0.7229.
# Epoch 4. Train Loss 0.6854. Train Acc 0.7621. Test Acc 0.6907.
# Epoch 5. Train Loss 0.6221. Train Acc 0.7853. Test Acc 0.7760.
# Epoch 6. Train Loss 0.5648. Train Acc 0.8055. Test Acc 0.7893.
# Epoch 7. Train Loss 0.5264. Train Acc 0.8167. Test Acc 0.7470.
# Epoch 8. Train Loss 0.4864. Train Acc 0.8331. Test Acc 0.8253.
# Epoch 9. Train Loss 0.4562. Train Acc 0.8419. Test Acc 0.8133.
# Epoch 10. Train Loss 0.4274. Train Acc 0.8537. Test Acc 0.8214.
# Epoch 11. Train Loss 0.4086. Train Acc 0.8598. Test Acc 0.8224.
# Epoch 12. Train Loss 0.3838. Train Acc 0.8687. Test Acc 0.8378.
# Epoch 13. Train Loss 0.3620. Train Acc 0.8757. Test Acc 0.8401.
# Epoch 14. Train Loss 0.3490. Train Acc 0.8795. Test Acc 0.8447.
# Epoch 15. Train Loss 0.3335. Train Acc 0.8848. Test Acc 0.8132.
# Epoch 16. Train Loss 0.3169. Train Acc 0.8916. Test Acc 0.8600.
# Epoch 17. Train Loss 0.3003. Train Acc 0.8965. Test Acc 0.8568.
# Epoch 18. Train Loss 0.2851. Train Acc 0.9025. Test Acc 0.8579.
# Epoch 19. Train Loss 0.2760. Train Acc 0.9060. Test Acc 0.8306.
# Epoch 20. Train Loss 0.2652. Train Acc 0.9100. Test Acc 0.8309.
# Epoch 21. Train Loss 0.2563. Train Acc 0.9127. Test Acc 0.8677.
# Epoch 22. Train Loss 0.2480. Train Acc 0.9145. Test Acc 0.8716.
# Epoch 23. Train Loss 0.2364. Train Acc 0.9203. Test Acc 0.8348.
# Epoch 24. Train Loss 0.2250. Train Acc 0.9226. Test Acc 0.8733.
# Epoch 25. Train Loss 0.2147. Train Acc 0.9263. Test Acc 0.8784.
# Epoch 26. Train Loss 0.2096. Train Acc 0.9285. Test Acc 0.8751.
# Epoch 27. Train Loss 0.2023. Train Acc 0.9308. Test Acc 0.8784.
# Epoch 28. Train Loss 0.1945. Train Acc 0.9327. Test Acc 0.8767.
# Epoch 29. Train Loss 0.1875. Train Acc 0.9352. Test Acc 0.8714.
# Epoch 30. Train Loss 0.1751. Train Acc 0.9394. Test Acc 0.8663.
# Epoch 31. Train Loss 0.1767. Train Acc 0.9386. Test Acc 0.8636.
# Epoch 32. Train Loss 0.1690. Train Acc 0.9422. Test Acc 0.8711.
# Epoch 33. Train Loss 0.1608. Train Acc 0.9446. Test Acc 0.8790.
# Epoch 34. Train Loss 0.1578. Train Acc 0.9467. Test Acc 0.8775.
# Epoch 35. Train Loss 0.1481. Train Acc 0.9499. Test Acc 0.8821.
# Epoch 36. Train Loss 0.1447. Train Acc 0.9510. Test Acc 0.8850.
# Epoch 37. Train Loss 0.1412. Train Acc 0.9525. Test Acc 0.8848.
# Epoch 38. Train Loss 0.1343. Train Acc 0.9550. Test Acc 0.8866.
# Epoch 39. Train Loss 0.1321. Train Acc 0.9557. Test Acc 0.8509.
# Epoch 40. Train Loss 0.1249. Train Acc 0.9577. Test Acc 0.8625.
# Epoch 41. Train Loss 0.1231. Train Acc 0.9591. Test Acc 0.8862.
# Epoch 42. Train Loss 0.1227. Train Acc 0.9599. Test Acc 0.8933.
# Epoch 43. Train Loss 0.1183. Train Acc 0.9607. Test Acc 0.8834.
# Epoch 44. Train Loss 0.1090. Train Acc 0.9639. Test Acc 0.8826.
# Epoch 45. Train Loss 0.1093. Train Acc 0.9635. Test Acc 0.8837.
# Epoch 46. Train Loss 0.1078. Train Acc 0.9641. Test Acc 0.8844.
# Epoch 47. Train Loss 0.1030. Train Acc 0.9653. Test Acc 0.8797.
# Epoch 48. Train Loss 0.0974. Train Acc 0.9679. Test Acc 0.8986.
# Epoch 49. Train Loss 0.0939. Train Acc 0.9695. Test Acc 0.8920.
